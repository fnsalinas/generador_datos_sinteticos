# %%
from typing import List, Dict, Tuple, Any
import requests
import json
import time
import random
from datetime import datetime
from glob import glob
import pandas as pd

# %%
URL: str = "http://3.130.56.233"

# %%
request = requests.get(f"{URL}/get_1_clients")
request.text
# Out:
# '[{"client_data":{"customer_id":"DEB1BFFDEEB7411B96703B8A8972ADFF","nif":"96188382J","first_name":"Marcos","last_name":"Alcaraz","date_of_birth":"2012-10-25","sex":"male","blood_group":"O+","city":"Ceuta","customer_address":"Alameda de Ramón Castillo 8\\nMurcia, 32402","lat":"12.153749","long":"30.896364","region":"Región de Murcia","timezone":"America/Mazatlan","customer_phone":"+34 745 490 269","customer_email":"coacacaa_052012@protonmail.com","customer_created_at":"2023-01-27 07:42:24 UTC","customer_updated_at":""},"user_data":{"user_id":"9019501A705C478595215F8AE1128B0A","customer_id":"DEB1BFFDEEB7411B96703B8A8972ADFF","user_name":"marcos_alcaraz_0009","user_password":"c3hm3nZv)OX","user_email":"coacacaa_052012@protonmail.com","user_phone":"+34 745 490 269","user_image_url":"https://placekitten.com/5/38","url":"https://www.nicolas.es/","user_created_at":"2023-01-27 07:42:24 UTC","user_updated_at":""},"product_data":{"product_id":"10A9DB9945704C56A75FDFB0B5903E7F","product_name":"Máquina de afeitar p/ hombre (Por Unidad)","product_description":"Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry\'s standard dummy text ever since the 1500s  when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries  but also the leap into electronic typesetting  remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages  and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.","product_price":"4524","product_category":"Aseo Personal","product_stock":"1407","product_rating":"1","product_rating_count":"634372","product_reviews_count":"446","product_reviews":"","product_tags":"Productos de higiene personal","product_created_at":"2000-01-01 12:00:00 UTC","product_updated_at":"2005-04-07 14:25:00 UTC"},"category_data":{"category_id":"5FB58B4F70B841FDBD264967B1CAA28F","category_name":"Aseo Personal","category_description":"Lorem Ipsum is simply dummy text of the ","category_image_url":"https://placekitten.com/387/782","category_created_at":"2000-01-01 12:00:00 UTC","category_updated_at":""},"order_data":{"order_id":"024E2075785346C6909B69517C869653","order_customer_id":"DEB1BFFDEEB7411B96703B8A8972ADFF","order_product_id":"10A9DB9945704C56A75FDFB0B5903E7F","order_quantity":7,"order_price":"4524","order_created_at":"2023-02-27 22:47:55 UTC","order_updated_at":""},"invoice_data":{"invoice_id":"79FD99DF968C4775ABB2C35C2909B190","invoice_customer_id":"DEB1BFFDEEB7411B96703B8A8972ADFF","invoice_order_id":"024E2075785346C6909B69517C869653","invoice_amount":"31668.0","invoice_created_at":"2023-02-22 16:45:23 UTC","invoice_updated_at":""}}]'

# %%
request = requests.get(f"{URL}/docs")
request.text
# Out:
# '\n    <!DOCTYPE html>\n    <html>\n    <head>\n    <link type="text/css" rel="stylesheet" href="https://cdn.jsdelivr.net/npm/swagger-ui-dist@4/swagger-ui.css">\n    <link rel="shortcut icon" href="https://fastapi.tiangolo.com/img/favicon.png">\n    <title>FastAPI - Swagger UI</title>\n    </head>\n    <body>\n    <div id="swagger-ui">\n    </div>\n    <script src="https://cdn.jsdelivr.net/npm/swagger-ui-dist@4/swagger-ui-bundle.js"></script>\n    <!-- `SwaggerUIBundle` is now available on the page -->\n    <script>\n    const ui = SwaggerUIBundle({\n        url: \'/openapi.json\',\n    "dom_id": "#swagger-ui",\n"layout": "BaseLayout",\n"deepLinking": true,\n"showExtensions": true,\n"showCommonExtensions": true,\noauth2RedirectUrl: window.location.origin + \'/docs/oauth2-redirect\',\n    presets: [\n        SwaggerUIBundle.presets.apis,\n        SwaggerUIBundle.SwaggerUIStandalonePreset\n        ],\n    })\n    </script>\n    </body>\n    </html>\n    '

# %%
noclients: int = 2
request = requests.get(f"{URL}/get_{noclients}_clients")
# json.loads(request.text)

# %%
download_path: str = "/home/ubuntu/workspace/fsalinas/generador_datos_sinteticos/data/downloaded_api"

while True:
    noclients: int = random.randint(1, 10)
    print((f"Downloading {noclients} clients" + " "*100)[:60], end="\r", flush=True)
    request = requests.get(f"{URL}/get_{noclients}_clients")
    clients = json.loads(request.text)
    ts_path: str = datetime.now().strftime("%Y%m%d_%H%M%S")
    with open(f"{download_path}/clients_{noclients}{ts_path}.json", "w") as output_file:
        json.dump(clients, output_file, indent=4)
    random_seconsdelay: int = random.randint(1, 10)
    print((f"Waiting {random_seconsdelay} seconds" + " "*100)[:60], end="\r", flush=True)
    for second in range(random_seconsdelay):
        print((f"Waiting {second} seconds of {random_seconsdelay} seconds" + " "*100)[:100], end="\r", flush=True)
        time.sleep(1)
# Out:
# Waiting 3 seconds of 10 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 15
#      13 for second in range(random_seconsdelay):
#      14     print((f"Waiting {second} seconds of {random_seconsdelay} seconds" + " "*100)[:100], end="\r", flush=True)
# ---> 15     time.sleep(1)
#
# KeyboardInterrupt:

# %%
json_files: List[str] = glob(f"{download_path}/*.json")
json_file: Dict[str, Any] = json_files[0]
file = open(json_file, "r")
json.loads(file.read())[0]
# Out:
# {'client_data': {'customer_id': '523F4790EF4841B4B81FF23538B20C38',
#   'nif': '09596240L',
#   'first_name': 'Reinaldo',
#   'last_name': 'Montserrat',
#   'date_of_birth': '2013-03-14',
#   'sex': 'male',
#   'blood_group': 'AB+',
#   'city': 'Lugo',
#   'customer_address': 'Rambla Pelayo Ángel 29\nGuadalajara, 22092',
#   'lat': '-51.1388215',
#   'long': '-56.383466',
#   'region': 'Galicia',
#   'timezone': 'Indian/Maldives',
#   'customer_phone': '+34958 706 000',
#   'customer_email': 'lrimsttrmren_0131@yahoo.com',
#   'customer_created_at': '2016-03-29 02:17:58 UTC',
#   'customer_updated_at': '2019-10-06 17:18:22 UTC'},
#  'user_data': {'user_id': 'F5AD78C6662545648BD127103267BCD7',
#   'customer_id': '523F4790EF4841B4B81FF23538B20C38',
#   'user_name': 'reinaldo_montserrat_3973',
#   'user_password': '@xwGwpgz4',
#   'user_email': 'lrimsttrmren_0131@yahoo.com',
#   'user_phone': '+34958 706 000',
#   'user_image_url': 'https://placekitten.com/543/116',
#   'url': 'https://roca.net/',
#   'user_created_at': '2016-03-29 02:17:58 UTC',
#   'user_updated_at': ''},
#  'product_data': {'product_id': 'C1066B8B8D6B4A699AA13138B92A3A4B',
#   'product_name': 'Pierna de cerdo (Kg.)',
#   'product_description': "Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s  when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries  but also the leap into electronic typesetting  remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages  and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.",
#   'product_price': '19968',
#   'product_category': 'Cárnicos',
#   'product_stock': '2610',
#   'product_rating': '5',
#   'product_rating_count': '58160',
#   'product_reviews_count': '321',
#   'product_reviews': '',
#   'product_tags': 'Productos de carne',
#   'product_created_at': '2000-01-01 12:00:00 UTC',
#   'product_updated_at': ''},
#  'category_data': {'category_id': '80D51F624E304E1785195E67C376000C',
#   'category_name': 'Cárnicos',
#   'category_description': 'Lorem Ipsum is simply dummy text of the ',
#   'category_image_url': 'https://placeimg.com/512/762/any',
#   'category_created_at': '2000-01-01 12:00:00 UTC',
#   'category_updated_at': ''},
#  'order_data': {'order_id': '10F75516269C4497A4B9D5CFE478B99A',
#   'order_customer_id': '523F4790EF4841B4B81FF23538B20C38',
#   'order_product_id': 'C1066B8B8D6B4A699AA13138B92A3A4B',
#   'order_quantity': 9,
#   'order_price': '19968',
#   'order_created_at': '2022-06-27 13:59:03 UTC',
#   'order_updated_at': ''},
#  'invoice_data': {'invoice_id': 'E4B3B9A07B184AE28A989A02BCECCEEB',
#   'invoice_customer_id': '523F4790EF4841B4B81FF23538B20C38',
#   'invoice_order_id': '10F75516269C4497A4B9D5CFE478B99A',
#   'invoice_amount': '179712.0',
#   'invoice_created_at': '2018-10-25 20:48:08 UTC',
#   'invoice_updated_at': ''}}

# %%
json_files: List[str] = glob(f"{download_path}/*.json")

list_of_dfs_client: List[pd.DataFrame] = []
list_of_dfs_user: List[pd.DataFrame] = []
list_of_dfs_product: List[pd.DataFrame] = []
list_of_dfs_category: List[pd.DataFrame] = []
list_of_dfs_order: List[pd.DataFrame] = []
list_of_dfs_invoice: List[pd.DataFrame] = []
for json_file in json_files:
    
    with open(json_file, "r") as input_file:
        clients = json.load(input_file)

    list_clients_data: List[Any] = []
    list_users_data: List[Any] = []
    list_products_data: List[Any] = []
    list_categories_data: List[Any] = []
    list_orders_data: List[Any] = []
    list_invoices_data: List[Any] = []
    for client in clients:
        list_clients_data.append(pd.DataFrame(client["client_data"], index=[0]))
        list_users_data.append(pd.DataFrame(client["user_data"], index=[0]))
        list_products_data.append(pd.DataFrame(client["product_data"], index=[0]))
        list_categories_data.append(pd.DataFrame(client["category_data"], index=[0]))
        list_orders_data.append(pd.DataFrame(client["order_data"], index=[0]))
        list_invoices_data.append(pd.DataFrame(client["invoice_data"], index=[0]))

    list_of_dfs_client.append(pd.concat(list_clients_data, ignore_index=True))
    list_of_dfs_user.append(pd.concat(list_users_data, ignore_index=True))
    list_of_dfs_product.append(pd.concat(list_products_data, ignore_index=True))
    list_of_dfs_category.append(pd.concat(list_categories_data, ignore_index=True))
    list_of_dfs_order.append(pd.concat(list_orders_data, ignore_index=True))
    list_of_dfs_invoice.append(pd.concat(list_invoices_data, ignore_index=True))

df_client = pd.concat(list_of_dfs_client, ignore_index=True)
df_user = pd.concat(list_of_dfs_user, ignore_index=True)
df_product = pd.concat(list_of_dfs_product, ignore_index=True)
df_category = pd.concat(list_of_dfs_category, ignore_index=True)
df_order = pd.concat(list_of_dfs_order, ignore_index=True)
df_invoice = pd.concat(list_of_dfs_invoice, ignore_index=True)

# %%
df_client
# Out:
#                           customer_id        nif first_name   last_name  \
# 0    523F4790EF4841B4B81FF23538B20C38  09596240L   Reinaldo  Montserrat
# 1    6E7E80288C5043B491F5E32ED3BC8F2C  30024725L   Raimundo     Soriano
# 2    232CC0AAB2E2423C8F9E075657421C43  69866266V    Adriana     Hurtado
# 3    987DDCE0A5A64915A87E5B1833B66F41  44179617K    Juanito     Piñeiro
# 4    787C68690F8042ED8014B25302CE04B8  78370410A   Verónica     Fuertes
# ..                                ...        ...        ...         ...
# 137  E01538DF79684617AF92BD33A78704D0  19379872A      Nydia     Canales
# 138  4EA2F1930B944E20B5FBA43C6C7E1A9F  74286118M     Néstor     Nicolau
# 139  5C20A00750FC41B58B48052174E242E4  35473581Z      Rocío   Caballero
# 140  16FE30154DC44B78ACD12C9E3FFD9A83  93826660T     Paloma      Cerdán
# 141  A765B138E0F940B6BBC07D7A420CED67  36243873J     Plinio        Seco
#
#     date_of_birth     sex blood_group        city  \
# 0      2013-03-14    male         AB+        Lugo
# 1      2011-07-27    male          B-      Huelva
# 2      1957-07-08  female         AB+   Castellón
# 3      1931-06-11    male          A-    Alicante
# 4      1914-03-27  female          A+       Álava
# ..            ...     ...         ...         ...
# 137    2013-12-24  female          O-  Pontevedra
# 138    2020-05-01    male          B+     Sevilla
# 139    1968-08-25  female         AB+    Alicante
# 140    2014-05-11  female          B+     Vizcaya
# 141    1980-04-04    male          B+     Cáceres
#
#                                       customer_address          lat  \
# 0           Rambla Pelayo Ángel 29\nGuadalajara, 22092  -51.1388215
# 1    Cañada Estela Ramos 1 Piso 3 \nGuadalajara, 48455    30.939696
# 2         Calle de Sigfrido Segarra 99\nCáceres, 22243   76.8014595
# 3      Vial Victorino Palomar 47 Piso 4 \nÁlava, 31552   64.7385525
# 4            Cañada de Amelia Cáceres 45\nÁlava, 24689   -65.683146
# ..                                                 ...          ...
# 137       Avenida Rosalina Gonzalez 355\nLleida, 29274   76.2620735
# 138   Calle Amador Sierra 35 Apt. 99 \nAlicante, 12466    -5.256966
# 139     Acceso Macarena Piñol 5 Piso 1 \nCiudad, 31847   81.4150165
# 140    Pasaje Óscar Botella 36 Apt. 55 \nHuesca, 49891  -19.9995195
# 141         Urbanización Paz Sedano 11\nCórdoba, 07571  -54.1290355
#
#             long                      region          timezone  \
# 0     -56.383466                     Galicia   Indian/Maldives
# 1     110.175603                   Cantabria  Australia/Sydney
# 2    -148.726945                    Cataluña      Europe/Minsk
# 3     130.765793  Comunidad Foral de Navarra     Europe/Zurich
# 4     -54.060576    Ciudad Autónoma de Ceuta   Africa/Freetown
# ..           ...                         ...               ...
# 137    15.345917               Illes Balears     Africa/Kigali
# 138    36.804705                   Andalucía  Africa/Mogadishu
# 139   -21.678078  Ciudad Autónoma de Melilla     Europe/Berlin
# 140   172.084501                 Extremadura   Indian/Maldives
# 141   -57.338387          Castilla-La Mancha      Asia/Jakarta
#
#        customer_phone                 customer_email      customer_created_at  \
# 0      +34958 706 000    lrimsttrmren_0131@yahoo.com  2016-03-29 02:17:58 UTC
# 1     +34849 47 07 33      ooumumioo_2107@yandex.com  2020-12-20 21:23:12 UTC
# 2    +34 975 64 59 32  aaaranhrd_09788097@icloud.com  2020-03-28 16:54:58 UTC
# 3    +34 949 13 40 91   juonnieeiñp1101@hushmail.com  2023-01-31 23:40:55 UTC
# 4     +34842 03 33 68    arróónfssfsf_7001@inbox.com  2020-07-20 23:45:03 UTC
# ..                ...                            ...                      ...
# 137   +34932 59 17 30         yiyayasn214102@aol.com  2022-03-22 21:41:04 UTC
# 138     +34 746567981        nrérrnnca_0025@mail.com  2022-06-08 05:13:56 UTC
# 139    +34886 499 730   oocícereoaaba286810@live.com  2020-07-21 19:42:05 UTC
# 140      +34988233522   mlpoalrdnná_4112020@mail.com  2022-10-18 23:32:18 UTC
# 141  +34 980 00 92 01          oiiosos804949@msn.com  2020-03-08 11:42:17 UTC
#
#          customer_updated_at
# 0    2019-10-06 17:18:22 UTC
# 1
# 2
# 3
# 4
# ..                       ...
# 137
# 138
# 139
# 140  2023-02-20 22:07:07 UTC
# 141
#
# [142 rows x 17 columns]
